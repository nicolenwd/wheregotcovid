# %% [markdown]
# ## Set-up

# %%
import numpy as np, pandas as pd, pdfplumber

# %%
pd.set_option('display.max_colwidth', None)
pd.options.display.max_rows = None

# %% [markdown]
# ## Extracting COVID-19 Case Visit Data from PDF

# %%
pdf = pdfplumber.open("..\data\moh_annex_jun_13.pdf")

# %%
len(range(0,3))
# Out:
# 3

# %%
# Extracting tables into dataframes
df_list = {}
for i in range(0,3):
    p = pdf.pages[i]
    tbl = p.extract_table()
    df_list[i] = pd.DataFrame(tbl[3:], columns=tbl[1])
    df_list[i].columns = ['Date', '', '', 'Time', '', '', 'Location', '', '']
    df_list[i] = df_list[i].dropna(axis=1, how="all")

# %%
# Binding all dataframes into one big dataframe
df_all_raw = pd.concat(df_list, ignore_index=True)
df_all_raw
# Out:
#                  Date            Time  \
# 0   30 May \nto 1 Jun  1230h to 2030h
# 1      30 to 31 \nMay  0000h to 2359h
# 2      30 to 31 \nMay  0645h to 1700h
# 3      30 to 31 \nMay  1200h to 1900h
# 4   30 May \nto 7 Jun  0600h to 1900h
# 5              30 May  1930h to 0000h
# 6              30 May  1100h to 2200h
# 7              30 May  1125h to 1200h
# 8              30 May  1200h to 1300h
# 9              30 May  1350h to 1440h
# 10             30 May  1550h to 1650h
# 11             30 May  1630h to 1700h
# 12             30 May  1800h to 1900h
# 13     30 to 31 \nMay  2005h to 0005h
# 14             31 May  1140h to 1500h
# 15             31 May  1835h to 1920h
# 16             31 May  1940h to 2010h
# 17              1 Jun  0735h to 0810h
# 18              1 Jun  0900h to 0930h
# 19              1 Jun  1000h to 1230h
# 20              1 Jun  1100h to 1230h
# 21              1 Jun  1725h to 1800h
# 22
# 23              1 Jun  1955h to 2030h
# 24              1 Jun  2100h to 2130h
# 25              2 Jun  1320h to 1420h
# 26              2 Jun  1420h to 1520h
# 27       3 to 6 \nJun  0645h to 1700h
# 28              3 Jun  0845h to 1050h
# 29              3 Jun  0900h to 1600h
# 30       3 to 4 \nJun  1230h to 2030h
# 31              3 Jun  1645h to 1720h
# 32              3 Jun  1900h to 1950h
# 33              3 Jun  1955h to 2035h
# 34              4 Jun  1300h to 2130h
# 35              5 Jun  0900h to 2130h
# 36              5 Jun  1000h to 1045h
# 37              5 Jun  1230h to 2030h
# 38       6 to 9 \nJun  0600h to 1400h
# 39              6 Jun  1000h to 1100h
# 40              6 Jun  1100h to 1145h
# 41              6 Jun  1230h to 2030h
# 42              6 Jun  1300h to 2130h
# 43              7 Jun  1230h to 2030h
# 44      8 to 10 \nJun  0730h to 0815h
# 45              8 Jun  0820h to 0900h
# 46              8 Jun  0920h to 1500h
# 47              8 Jun  1025h to 1100h
# 48              8 Jun  1100h to 1345h
# 49              8 Jun  2015h to 2045h
# 50      9 to 11 \nJun  0500h to 1800h
# 51      9 to 10 \nJun  0600h to 1900h
# 52              9 Jun  0800h to 1500h
# 53              9 Jun  1230h to 2030h
# 54              9 Jun  1510h to 1550h
# 55             10 Jun  1205h to 1310h
# 56             11 Jun  0600h to 0900h
# 57             11 Jun  1030h to 1900h
# 58             12 Jun  0500h to 0530h
#
#                                                                    Location
# 0                                ION Orchard (2 Orchard Turn) \n  Guardian
# 1                                     Tuas Amenity Centre (71 Pioneer Road)
# 2                           Takashimaya (391A Orchard Road) \n  St. Leaven
# 3                                       Atatcutz Singapore (348 Bedok Road)
# 4                                              ION Orchard (2 Orchard Turn)
# 5                                       NTUC Foodfare (308 Anchorvale Road)
# 6         Hougang Green Shopping Mall (21 Hougang Street 51) \n  Pizza Hut
# 7                                 Ang Mo Supermarket (642 Hougang Avenue 8)
# 8                                         Bugis Street (3 New Bugis Street)
# 9                                    NTUC FairPrice (37 Teban Gardens Road)
# 10                 Choa Chu Kang Columbarium (51 Chinese Cemetery Path \n4)
# 11      Marsiling Mall (4 Woodlands Street 12) \n  Sheng Siong Supermarket
# 12  Hong Yang Health Products & Foot Reflexology Centre (38 \nBeo Crescent)
# 13                             Marina Bay Sands Casino (10 Bayfront Avenue)
# 14                       Marina Bay Sands (2 Bayfront Avenue) \n  Church’s
# 15                Woodlands Galaxy Community Club (31 Woodlands \nAvenue 6)
# 16                                Sheng Siong Supermarket (446A Fajar Road)
# 17                                Sheng Siong Supermarket (446A Fajar Road)
# 18                                   Beo Crescent Market (38A Beo Crescent)
# 19                                JIC Inspection Services (53 Pioneer Road)
# 20                       VICOM Inspection Centre (511 Bukit Batok Street 2)
# 21                                 Yew Tee Point (21 Choa Chu Kang North 6)
# 22                                                          NTUC FairPrice
# 23             Seletar Mall (33 Sengkang West Avenue) \n  FairPrice Finest
# 24                     HDB Hub (500 Toa Payoh Lorong 6) \n  NTUC FairPrice
# 25                     Novena Square 2 (10 Sinaran Drive) \n  Hush Puppies
# 26                                Velocity@Novena Square (238 Thomson Road)
# 27                          Takashimaya (391A Orchard Road) \n  St. Leaven
# 28                        ION Orchard (2 Orchard Turn) \n  Dolce & Gabbana
# 29                            ION Orchard (2 Orchard Turn) \n  Four Leaves
# 30                               ION Orchard (2 Orchard Turn) \n  Guardian
# 31            People’s Park Complex (1 Park Road) \n  Scarlett Supermarket
# 32                                  Peninsula Plaza (111 North Bridge Road)
# 33                                      Mustafa Centre (145 Syed Alwi Road)
# 34                            ION Orchard (2 Orchard Turn) \n  Four Leaves
# 35                            ION Orchard (2 Orchard Turn) \n  Four Leaves
# 36                                  Divine Beauty (303 Woodlands Street 31)
# 37                               ION Orchard (2 Orchard Turn) \n  Guardian
# 38     115 Bukit Merah View Market & Hawker Centre (115 Bukit \nMerah View)
# 39                        The Centrepoint (176 Orchard Road) \n  Decathlon
# 40                           Orchard Central (181 Orchard Road) \n  UNIQLO
# 41                               ION Orchard (2 Orchard Turn) \n  Guardian
# 42                            ION Orchard (2 Orchard Turn) \n  Four Leaves
# 43                               ION Orchard (2 Orchard Turn) \n  Guardian
# 44                                         Redhill Market (79 Redhill Lane)
# 45                    Tiong Bahru Market and Food Centre (30 Seng Poh Road)
# 46     115 Bukit Merah View Market & Hawker Centre (115 Bukit \nMerah View)
# 47                                        NTUC FairPrice (50 Havelock Road)
# 48                      The One Hairstyling Studio (123 Lorong 1 Toa Payoh)
# 49                        Ang Mo Kio MRT Station (2450 Ang Mo Kio Avenue 8)
# 50     115 Bukit Merah View Market & Hawker Centre (115 Bukit \nMerah View)
# 51                                             ION Orchard (2 Orchard Turn)
# 52     115 Bukit Merah View Market & Hawker Centre (115 Bukit \nMerah View)
# 53                               ION Orchard (2 Orchard Turn) \n  Guardian
# 54           Tiong Bahru Plaza (298 Tiong Bahru Road) \n  FairPrice Finest
# 55                              Renee Hair Salon (756 Upper Serangoon Road)
# 56                                             ION Orchard (2 Orchard Turn)
# 57                                             ION Orchard (2 Orchard Turn)
# 58     115 Bukit Merah View Market & Hawker Centre (115 Bukit \nMerah View)

# %%
## Data Cleaning
# Replacing values that neeed to be reformatted
df_all_raw.loc[21, 'Location'] = "Yew Tee Point (21 Choa Chu Kang North 6): NTUC FairPrice"

# Cleaning unknown characters ("\uf0b7"), line breaks ("\n") and other inconsistencies in data
df_all_raw['Date'] = df_all_raw['Date'].str.replace("\n", "")
df_all_raw['Time'] = df_all_raw['Time'].str.replace("1030h to 1900j", 
                                                            "1030h to 1900h")
df_all_raw['Location'] = df_all_raw['Location'].str.replace("’", "'") 
df_all_raw['Location'] = df_all_raw['Location'].str.replace("\n", "")
df_all_raw['Location'] = df_all_raw['Location'].str.replace(" \uf0b7", ":", n=1)
df_all_raw['Location'] = df_all_raw['Location'].str.replace(" \uf0b7", ",")
df_all_raw['Location'] = df_all_raw['Location'].str.replace(" :", ":")

# Removing redundant rows
df_all_clean = df_all_raw.drop([22]) 
df_all_clean = df_all_clean.reset_index(drop=True)

# %%
display(df_all_clean)
df_all_clean.shape
# Out:
#                Date            Time  \
# 0   30 May to 1 Jun  1230h to 2030h
# 1      30 to 31 May  0000h to 2359h
# 2      30 to 31 May  0645h to 1700h
# 3      30 to 31 May  1200h to 1900h
# 4   30 May to 7 Jun  0600h to 1900h
# 5            30 May  1930h to 0000h
# 6            30 May  1100h to 2200h
# 7            30 May  1125h to 1200h
# 8            30 May  1200h to 1300h
# 9            30 May  1350h to 1440h
# 10           30 May  1550h to 1650h
# 11           30 May  1630h to 1700h
# 12           30 May  1800h to 1900h
# 13     30 to 31 May  2005h to 0005h
# 14           31 May  1140h to 1500h
# 15           31 May  1835h to 1920h
# 16           31 May  1940h to 2010h
# 17            1 Jun  0735h to 0810h
# 18            1 Jun  0900h to 0930h
# 19            1 Jun  1000h to 1230h
# 20            1 Jun  1100h to 1230h
# 21            1 Jun  1725h to 1800h
# 22            1 Jun  1955h to 2030h
# 23            1 Jun  2100h to 2130h
# 24            2 Jun  1320h to 1420h
# 25            2 Jun  1420h to 1520h
# 26       3 to 6 Jun  0645h to 1700h
# 27            3 Jun  0845h to 1050h
# 28            3 Jun  0900h to 1600h
# 29       3 to 4 Jun  1230h to 2030h
# 30            3 Jun  1645h to 1720h
# 31            3 Jun  1900h to 1950h
# 32            3 Jun  1955h to 2035h
# 33            4 Jun  1300h to 2130h
# 34            5 Jun  0900h to 2130h
# 35            5 Jun  1000h to 1045h
# 36            5 Jun  1230h to 2030h
# 37       6 to 9 Jun  0600h to 1400h
# 38            6 Jun  1000h to 1100h
# 39            6 Jun  1100h to 1145h
# 40            6 Jun  1230h to 2030h
# 41            6 Jun  1300h to 2130h
# 42            7 Jun  1230h to 2030h
# 43      8 to 10 Jun  0730h to 0815h
# 44            8 Jun  0820h to 0900h
# 45            8 Jun  0920h to 1500h
# 46            8 Jun  1025h to 1100h
# 47            8 Jun  1100h to 1345h
# 48            8 Jun  2015h to 2045h
# 49      9 to 11 Jun  0500h to 1800h
# 50      9 to 10 Jun  0600h to 1900h
# 51            9 Jun  0800h to 1500h
# 52            9 Jun  1230h to 2030h
# 53            9 Jun  1510h to 1550h
# 54           10 Jun  1205h to 1310h
# 55           11 Jun  0600h to 0900h
# 56           11 Jun  1030h to 1900h
# 57           12 Jun  0500h to 0530h
#
#                                                                  Location
# 0                                 ION Orchard (2 Orchard Turn):  Guardian
# 1                                   Tuas Amenity Centre (71 Pioneer Road)
# 2                            Takashimaya (391A Orchard Road):  St. Leaven
# 3                                     Atatcutz Singapore (348 Bedok Road)
# 4                                            ION Orchard (2 Orchard Turn)
# 5                                     NTUC Foodfare (308 Anchorvale Road)
# 6          Hougang Green Shopping Mall (21 Hougang Street 51):  Pizza Hut
# 7                               Ang Mo Supermarket (642 Hougang Avenue 8)
# 8                                       Bugis Street (3 New Bugis Street)
# 9                                  NTUC FairPrice (37 Teban Gardens Road)
# 10                 Choa Chu Kang Columbarium (51 Chinese Cemetery Path 4)
# 11       Marsiling Mall (4 Woodlands Street 12):  Sheng Siong Supermarket
# 12  Hong Yang Health Products & Foot Reflexology Centre (38 Beo Crescent)
# 13                           Marina Bay Sands Casino (10 Bayfront Avenue)
# 14                        Marina Bay Sands (2 Bayfront Avenue):  Church's
# 15                Woodlands Galaxy Community Club (31 Woodlands Avenue 6)
# 16                              Sheng Siong Supermarket (446A Fajar Road)
# 17                              Sheng Siong Supermarket (446A Fajar Road)
# 18                                 Beo Crescent Market (38A Beo Crescent)
# 19                              JIC Inspection Services (53 Pioneer Road)
# 20                     VICOM Inspection Centre (511 Bukit Batok Street 2)
# 21               Yew Tee Point (21 Choa Chu Kang North 6): NTUC FairPrice
# 22              Seletar Mall (33 Sengkang West Avenue):  FairPrice Finest
# 23                      HDB Hub (500 Toa Payoh Lorong 6):  NTUC FairPrice
# 24                      Novena Square 2 (10 Sinaran Drive):  Hush Puppies
# 25                              Velocity@Novena Square (238 Thomson Road)
# 26                           Takashimaya (391A Orchard Road):  St. Leaven
# 27                         ION Orchard (2 Orchard Turn):  Dolce & Gabbana
# 28                             ION Orchard (2 Orchard Turn):  Four Leaves
# 29                                ION Orchard (2 Orchard Turn):  Guardian
# 30             People's Park Complex (1 Park Road):  Scarlett Supermarket
# 31                                Peninsula Plaza (111 North Bridge Road)
# 32                                    Mustafa Centre (145 Syed Alwi Road)
# 33                             ION Orchard (2 Orchard Turn):  Four Leaves
# 34                             ION Orchard (2 Orchard Turn):  Four Leaves
# 35                                Divine Beauty (303 Woodlands Street 31)
# 36                                ION Orchard (2 Orchard Turn):  Guardian
# 37     115 Bukit Merah View Market & Hawker Centre (115 Bukit Merah View)
# 38                         The Centrepoint (176 Orchard Road):  Decathlon
# 39                            Orchard Central (181 Orchard Road):  UNIQLO
# 40                                ION Orchard (2 Orchard Turn):  Guardian
# 41                             ION Orchard (2 Orchard Turn):  Four Leaves
# 42                                ION Orchard (2 Orchard Turn):  Guardian
# 43                                       Redhill Market (79 Redhill Lane)
# 44                  Tiong Bahru Market and Food Centre (30 Seng Poh Road)
# 45     115 Bukit Merah View Market & Hawker Centre (115 Bukit Merah View)
# 46                                      NTUC FairPrice (50 Havelock Road)
# 47                    The One Hairstyling Studio (123 Lorong 1 Toa Payoh)
# 48                      Ang Mo Kio MRT Station (2450 Ang Mo Kio Avenue 8)
# 49     115 Bukit Merah View Market & Hawker Centre (115 Bukit Merah View)
# 50                                           ION Orchard (2 Orchard Turn)
# 51     115 Bukit Merah View Market & Hawker Centre (115 Bukit Merah View)
# 52                                ION Orchard (2 Orchard Turn):  Guardian
# 53            Tiong Bahru Plaza (298 Tiong Bahru Road):  FairPrice Finest
# 54                            Renee Hair Salon (756 Upper Serangoon Road)
# 55                                           ION Orchard (2 Orchard Turn)
# 56                                           ION Orchard (2 Orchard Turn)
# 57     115 Bukit Merah View Market & Hawker Centre (115 Bukit Merah View)
# (58, 3)

# %%
# Splitting Store info into separate column
df_all_clean_split = df_all_clean.copy(deep=True)
df_all_clean_split[['Location', 'Store']] = df_all_clean_split['Location'].str.split(pat=': ', n=1, expand=True)
df_all_clean_split['Store'] = df_all_clean_split['Store'].str.strip()

# %%
# Splitting Address info into separate column
df_all_clean_split[['Location','Address']] = df_all_clean_split['Location'].str.split(pat='(', n=1, expand=True)
df_all_clean_split['Address'] = df_all_clean_split['Address'].str.replace(")", "", regex=False)
df_all_clean_split['Address'] = df_all_clean_split['Address'].str.strip()
df_all_clean_split
# Out:
#                Date            Time  \
# 0   30 May to 1 Jun  1230h to 2030h
# 1      30 to 31 May  0000h to 2359h
# 2      30 to 31 May  0645h to 1700h
# 3      30 to 31 May  1200h to 1900h
# 4   30 May to 7 Jun  0600h to 1900h
# 5            30 May  1930h to 0000h
# 6            30 May  1100h to 2200h
# 7            30 May  1125h to 1200h
# 8            30 May  1200h to 1300h
# 9            30 May  1350h to 1440h
# 10           30 May  1550h to 1650h
# 11           30 May  1630h to 1700h
# 12           30 May  1800h to 1900h
# 13     30 to 31 May  2005h to 0005h
# 14           31 May  1140h to 1500h
# 15           31 May  1835h to 1920h
# 16           31 May  1940h to 2010h
# 17            1 Jun  0735h to 0810h
# 18            1 Jun  0900h to 0930h
# 19            1 Jun  1000h to 1230h
# 20            1 Jun  1100h to 1230h
# 21            1 Jun  1725h to 1800h
# 22            1 Jun  1955h to 2030h
# 23            1 Jun  2100h to 2130h
# 24            2 Jun  1320h to 1420h
# 25            2 Jun  1420h to 1520h
# 26       3 to 6 Jun  0645h to 1700h
# 27            3 Jun  0845h to 1050h
# 28            3 Jun  0900h to 1600h
# 29       3 to 4 Jun  1230h to 2030h
# 30            3 Jun  1645h to 1720h
# 31            3 Jun  1900h to 1950h
# 32            3 Jun  1955h to 2035h
# 33            4 Jun  1300h to 2130h
# 34            5 Jun  0900h to 2130h
# 35            5 Jun  1000h to 1045h
# 36            5 Jun  1230h to 2030h
# 37       6 to 9 Jun  0600h to 1400h
# 38            6 Jun  1000h to 1100h
# 39            6 Jun  1100h to 1145h
# 40            6 Jun  1230h to 2030h
# 41            6 Jun  1300h to 2130h
# 42            7 Jun  1230h to 2030h
# 43      8 to 10 Jun  0730h to 0815h
# 44            8 Jun  0820h to 0900h
# 45            8 Jun  0920h to 1500h
# 46            8 Jun  1025h to 1100h
# 47            8 Jun  1100h to 1345h
# 48            8 Jun  2015h to 2045h
# 49      9 to 11 Jun  0500h to 1800h
# 50      9 to 10 Jun  0600h to 1900h
# 51            9 Jun  0800h to 1500h
# 52            9 Jun  1230h to 2030h
# 53            9 Jun  1510h to 1550h
# 54           10 Jun  1205h to 1310h
# 55           11 Jun  0600h to 0900h
# 56           11 Jun  1030h to 1900h
# 57           12 Jun  0500h to 0530h
#
#                                                 Location  \
# 0                                           ION Orchard
# 1                                   Tuas Amenity Centre
# 2                                           Takashimaya
# 3                                    Atatcutz Singapore
# 4                                           ION Orchard
# 5                                         NTUC Foodfare
# 6                           Hougang Green Shopping Mall
# 7                                    Ang Mo Supermarket
# 8                                          Bugis Street
# 9                                        NTUC FairPrice
# 10                            Choa Chu Kang Columbarium
# 11                                       Marsiling Mall
# 12  Hong Yang Health Products & Foot Reflexology Centre
# 13                              Marina Bay Sands Casino
# 14                                     Marina Bay Sands
# 15                      Woodlands Galaxy Community Club
# 16                              Sheng Siong Supermarket
# 17                              Sheng Siong Supermarket
# 18                                  Beo Crescent Market
# 19                              JIC Inspection Services
# 20                              VICOM Inspection Centre
# 21                                        Yew Tee Point
# 22                                         Seletar Mall
# 23                                              HDB Hub
# 24                                      Novena Square 2
# 25                               Velocity@Novena Square
# 26                                          Takashimaya
# 27                                          ION Orchard
# 28                                          ION Orchard
# 29                                          ION Orchard
# 30                                People's Park Complex
# 31                                      Peninsula Plaza
# 32                                       Mustafa Centre
# 33                                          ION Orchard
# 34                                          ION Orchard
# 35                                        Divine Beauty
# 36                                          ION Orchard
# 37          115 Bukit Merah View Market & Hawker Centre
# 38                                      The Centrepoint
# 39                                      Orchard Central
# 40                                          ION Orchard
# 41                                          ION Orchard
# 42                                          ION Orchard
# 43                                       Redhill Market
# 44                   Tiong Bahru Market and Food Centre
# 45          115 Bukit Merah View Market & Hawker Centre
# 46                                       NTUC FairPrice
# 47                           The One Hairstyling Studio
# 48                               Ang Mo Kio MRT Station
# 49          115 Bukit Merah View Market & Hawker Centre
# 50                                          ION Orchard
# 51          115 Bukit Merah View Market & Hawker Centre
# 52                                          ION Orchard
# 53                                    Tiong Bahru Plaza
# 54                                     Renee Hair Salon
# 55                                          ION Orchard
# 56                                          ION Orchard
# 57          115 Bukit Merah View Market & Hawker Centre
#
#                       Store                     Address
# 0                  Guardian              2 Orchard Turn
# 1                      None             71 Pioneer Road
# 2                St. Leaven           391A Orchard Road
# 3                      None              348 Bedok Road
# 4                      None              2 Orchard Turn
# 5                      None         308 Anchorvale Road
# 6                 Pizza Hut        21 Hougang Street 51
# 7                      None        642 Hougang Avenue 8
# 8                      None          3 New Bugis Street
# 9                      None       37 Teban Gardens Road
# 10                     None  51 Chinese Cemetery Path 4
# 11  Sheng Siong Supermarket       4 Woodlands Street 12
# 12                     None             38 Beo Crescent
# 13                     None          10 Bayfront Avenue
# 14                 Church's           2 Bayfront Avenue
# 15                     None       31 Woodlands Avenue 6
# 16                     None             446A Fajar Road
# 17                     None             446A Fajar Road
# 18                     None            38A Beo Crescent
# 19                     None             53 Pioneer Road
# 20                     None    511 Bukit Batok Street 2
# 21           NTUC FairPrice    21 Choa Chu Kang North 6
# 22         FairPrice Finest     33 Sengkang West Avenue
# 23           NTUC FairPrice      500 Toa Payoh Lorong 6
# 24             Hush Puppies            10 Sinaran Drive
# 25                     None            238 Thomson Road
# 26               St. Leaven           391A Orchard Road
# 27          Dolce & Gabbana              2 Orchard Turn
# 28              Four Leaves              2 Orchard Turn
# 29                 Guardian              2 Orchard Turn
# 30     Scarlett Supermarket                 1 Park Road
# 31                     None       111 North Bridge Road
# 32                     None          145 Syed Alwi Road
# 33              Four Leaves              2 Orchard Turn
# 34              Four Leaves              2 Orchard Turn
# 35                     None     303 Woodlands Street 31
# 36                 Guardian              2 Orchard Turn
# 37                     None        115 Bukit Merah View
# 38                Decathlon            176 Orchard Road
# 39                   UNIQLO            181 Orchard Road
# 40                 Guardian              2 Orchard Turn
# 41              Four Leaves              2 Orchard Turn
# 42                 Guardian              2 Orchard Turn
# 43                     None             79 Redhill Lane
# 44                     None            30 Seng Poh Road
# 45                     None        115 Bukit Merah View
# 46                     None            50 Havelock Road
# 47                     None      123 Lorong 1 Toa Payoh
# 48                     None    2450 Ang Mo Kio Avenue 8
# 49                     None        115 Bukit Merah View
# 50                     None              2 Orchard Turn
# 51                     None        115 Bukit Merah View
# 52                 Guardian              2 Orchard Turn
# 53         FairPrice Finest        298 Tiong Bahru Road
# 54                     None    756 Upper Serangoon Road
# 55                     None              2 Orchard Turn
# 56                     None              2 Orchard Turn
# 57                     None        115 Bukit Merah View

# %%
df_all_clean_split.to_csv('../data/visit_data_raw.csv')
